jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4203.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1538.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3706.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1252.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1861.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4928.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1849.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2212.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2461.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0843.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1236.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/5051.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3536.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0001.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2151.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3911.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1976.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1515.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1141.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3737.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3496.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4335.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4143.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2861.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0870.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2769.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0492.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2710.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3774.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3882.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2092.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4680.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0176.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3349.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0391.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0556.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2884.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3695.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2969.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4466.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1903.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2689.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3613.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4678.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/5252.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0788.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3495.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2607.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2691.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4490.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3267.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1201.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3120.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2867.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/5272.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1801.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/0269.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3000.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4421.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1979.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3059.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3410.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2085.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4968.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/5005.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/5088.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/5254.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/4463.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3950.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/1656.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/3361.jpg
# /kaggle/input/brain-tumour-classification/BrainTumor_1/Train/glioma/2599.jpg

# %%
base_path = "/kaggle/input/brain-tumour-classification/BrainTumor_1/Train"
categories = ["glioma", "meningioma", "notumor", "pituitary"]

# %%
image_paths = []
labels = []

for category in categories:
    category_path = os.path.join(base_path, category)
    for image_name in os.listdir(category_path):
        image_path = os.path.join(category_path, image_name)
        image_paths.append(image_path)
        labels.append(category)  

df = pd.DataFrame({
    "image_path": image_paths,
    "label": labels
})

# %%
df.head()
# Out:
#                                           image_path   label
# 0  /kaggle/input/brain-tumour-classification/Brai...  glioma
# 1  /kaggle/input/brain-tumour-classification/Brai...  glioma
# 2  /kaggle/input/brain-tumour-classification/Brai...  glioma
# 3  /kaggle/input/brain-tumour-classification/Brai...  glioma
# 4  /kaggle/input/brain-tumour-classification/Brai...  glioma

# %%
df.tail()
# Out:
#                                               image_path      label
# 22843  /kaggle/input/brain-tumour-classification/Brai...  pituitary
# 22844  /kaggle/input/brain-tumour-classification/Brai...  pituitary
# 22845  /kaggle/input/brain-tumour-classification/Brai...  pituitary
# 22846  /kaggle/input/brain-tumour-classification/Brai...  pituitary
# 22847  /kaggle/input/brain-tumour-classification/Brai...  pituitary

# %%
df.shape
# Out:
# (22848, 2)

# %%
df.columns
# Out:
# Index(['image_path', 'label'], dtype='object')

# %%
df['label'].unique()
# Out:
# array(['glioma', 'meningioma', 'notumor', 'pituitary'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# notumor       6380
# pituitary     5828
# meningioma    5356
# glioma        5284
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="label", palette="viridis")
plt.title("Distribution of Labels - Count Plot")
plt.xlabel("Tumor Type")
plt.ylabel("Count")

for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=11, color='black', xytext=(0, 5), 
                       textcoords='offset points')

plt.show()

label_counts = df['label'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis"))
plt.title("Distribution of Labels - Pie Chart")
plt.show()

# %%
import cv2

num_images = 5

plt.figure(figsize=(15, 12))

for i, category in enumerate(categories):
    category_images = df[df['label'] == category]['image_path'].iloc[:num_images]

    for j, img_path in enumerate(category_images):

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  

        plt.subplot(len(categories), num_images, i * num_images + j + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(category)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['category_encoded'] = label_encoder.fit_transform(df['label'])

# %%
df = df[['image_path', 'category_encoded']]

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df[['image_path']], df['category_encoded'])

# %%
df_resampled = pd.DataFrame(X_resampled, columns=['image_path'])
df_resampled['category_encoded'] = y_resampled

# %%
print("\nClass distribution after oversampling:")
print(df_resampled['category_encoded'].value_counts())
# Out:
# Class distribution after oversampling:
# category_encoded
# 0    6380
# 1    6380
# 2    6380
# 3    6380
# Name: count, dtype: int64

# %%
df_resampled
# Out:
#                                               image_path  category_encoded
# 0      /kaggle/input/brain-tumour-classification/Brai...                 0
# 1      /kaggle/input/brain-tumour-classification/Brai...                 0
# 2      /kaggle/input/brain-tumour-classification/Brai...                 0
# 3      /kaggle/input/brain-tumour-classification/Brai...                 0
# 4      /kaggle/input/brain-tumour-classification/Brai...                 0
# ...                                                  ...               ...
# 25515  /kaggle/input/brain-tumour-classification/Brai...                 3
# 25516  /kaggle/input/brain-tumour-classification/Brai...                 3
# 25517  /kaggle/input/brain-tumour-classification/Brai...                 3
# 25518  /kaggle/input/brain-tumour-classification/Brai...                 3
# 25519  /kaggle/input/brain-tumour-classification/Brai...                 3
#
# [25520 rows x 2 columns]

# %%
import time
import shutil
import pathlib
import itertools
from PIL import Image

import cv2
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

import warnings
warnings.filterwarnings("ignore")

print ('check')
# Out:
# check

# %%
df_resampled['category_encoded'] = df_resampled['category_encoded'].astype(str)

# %%
train_df_new, temp_df_new = train_test_split(
    df_resampled,
    train_size=0.8,  
    shuffle=True,
    random_state=42,
    stratify=df_resampled['category_encoded']  
)

valid_df_new, test_df_new = train_test_split(
    temp_df_new,
    test_size=0.5,  
    shuffle=True,
    random_state=42,
    stratify=temp_df_new['category_encoded'] 
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch_size = 16
img_size = (224, 224)
channels = 3  
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator(rescale=1./255)  
ts_gen = ImageDataGenerator(rescale=1./255)

train_gen_new = tr_gen.flow_from_dataframe(
    train_df_new,
    x_col='image_path',  
    y_col='category_encoded',     
    target_size=img_size,
    class_mode='sparse',  
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size
)

valid_gen_new = ts_gen.flow_from_dataframe(
    valid_df_new,
    x_col='image_path',  
    y_col='category_encoded',     
    target_size=img_size,
    class_mode='sparse',  
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size
)

test_gen_new = ts_gen.flow_from_dataframe(
    test_df_new,
    x_col='image_path', 
    y_col='category_encoded',    
    target_size=img_size,
    class_mode='sparse',  
    color_mode='rgb', 
    shuffle=False,  
    batch_size=batch_size
)
# Out:
# Found 20416 validated image filenames belonging to 4 classes.
# Found 2552 validated image filenames belonging to 4 classes.
# Found 2552 validated image filenames belonging to 4 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# Using GPU

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, 
                                     GaussianNoise, Input, MultiHeadAttention, Reshape)
from tensorflow.keras.optimizers import Adam

def create_vgg16_model(input_shape):
   
    inputs = Input(shape=input_shape)
    
    base_model = VGG16(weights='imagenet', input_tensor=inputs, include_top=False)
    
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output

    height, width, channels = 7, 7, 512  
    x = Reshape((height * width, channels))(x)
    
    attention_output = MultiHeadAttention(num_heads=8, key_dim=channels)(x, x)
    attention_output = Reshape((height, width, channels))(attention_output)
    
    x = GaussianNoise(0.25)(attention_output)
    
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = GaussianNoise(0.25)(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(4, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)

    return model

input_shape = (224, 224, 3)

cnn_model = create_vgg16_model(input_shape)

cnn_model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = cnn_model.fit(
    train_gen_new,
    validation_data=valid_gen_new,
    epochs=5,  
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732454798.235288      73 service.cc:145] XLA service 0x7fb450007930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732454798.235351      73 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1732454798.235355      73 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732454809.221664     107 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 1284 bytes spill stores, 1272 bytes spill loads
#    1/1276 ━━━━━━━━━━━━━━━━━━━━ 9:15:27 26s/step - accuracy: 0.6250 - loss: 1.0064
# I0000 00:00:1732454820.964557      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7731 - loss: 0.6083
# I0000 00:00:1732454964.922287     165 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_6', 1280 bytes spill stores, 1268 bytes spill loads
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 178s 119ms/step - accuracy: 0.7732 - loss: 0.6082 - val_accuracy: 0.5204 - val_loss: 1.5610
# Epoch 2/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 139s 109ms/step - accuracy: 0.8764 - loss: 0.3423 - val_accuracy: 0.8883 - val_loss: 0.3278
# Epoch 3/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 136s 107ms/step - accuracy: 0.9075 - loss: 0.2504 - val_accuracy: 0.5913 - val_loss: 1.6450
# Epoch 4/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 129s 101ms/step - accuracy: 0.9265 - loss: 0.2059 - val_accuracy: 0.8915 - val_loss: 0.3549
# Epoch 5/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 137s 107ms/step - accuracy: 0.9362 - loss: 0.1746 - val_accuracy: 0.8781 - val_loss: 0.3702

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
test_labels = test_gen_new.classes  
predictions = cnn_model.predict(test_gen_new)  
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step

# %%
report = classification_report(test_labels, predicted_classes, target_names=list(test_gen_new.class_indices.keys()))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       638
#            1       0.78      0.94      0.85       638
#            2       1.00      0.86      0.93       638
#            3       0.97      0.85      0.91       638
#
#     accuracy                           0.89      2552
#    macro avg       0.91      0.89      0.90      2552
# weighted avg       0.91      0.89      0.90      2552

# %%
conf_matrix = confusion_matrix(test_labels, predicted_classes)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=list(test_gen_new.class_indices.keys()), yticklabels=list(test_gen_new.class_indices.keys()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, GaussianNoise, Input, MultiHeadAttention, Reshape
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

def create_vgg19_model(input_shape):
  
    inputs = Input(shape=input_shape)
    
    base_model = VGG19(weights='imagenet', input_tensor=inputs, include_top=False)
    
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output

    height, width, channels = 7, 7, 512   
    x = Reshape((height * width, channels))(x)
   
    attention_output = MultiHeadAttention(num_heads=8, key_dim=channels)(x, x)

    attention_output = Reshape((height, width, channels))(attention_output)
    
    x = GaussianNoise(0.25)(attention_output)
    
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = GaussianNoise(0.25)(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(4, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)

    return model

input_shape = (224, 224, 3)

cnn_model = create_vgg19_model(input_shape)

cnn_model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = cnn_model.fit(
    train_gen_new,
    validation_data=valid_gen_new,
    epochs=5,  
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 171s 128ms/step - accuracy: 0.7348 - loss: 0.6886 - val_accuracy: 0.8170 - val_loss: 0.4725
# Epoch 2/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 162s 126ms/step - accuracy: 0.8750 - loss: 0.3366 - val_accuracy: 0.8738 - val_loss: 0.3714
# Epoch 3/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 161s 126ms/step - accuracy: 0.9005 - loss: 0.2673 - val_accuracy: 0.7700 - val_loss: 0.8444
# Epoch 4/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 162s 127ms/step - accuracy: 0.9203 - loss: 0.2283 - val_accuracy: 0.8629 - val_loss: 0.3802
# Epoch 5/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 161s 126ms/step - accuracy: 0.9325 - loss: 0.1890 - val_accuracy: 0.8668 - val_loss: 0.4201

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
test_labels = test_gen_new.classes  
predictions = cnn_model.predict(test_gen_new)  
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step

# %%
report = classification_report(test_labels, predicted_classes, target_names=list(test_gen_new.class_indices.keys()))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82       638
#            1       0.89      0.54      0.67       638
#            2       0.82      0.98      0.89       638
#            3       0.94      0.87      0.90       638
#
#     accuracy                           0.83      2552
#    macro avg       0.85      0.83      0.82      2552
# weighted avg       0.85      0.83      0.82      2552

# %%
conf_matrix = confusion_matrix(test_labels, predicted_classes)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=list(test_gen_new.class_indices.keys()), yticklabels=list(test_gen_new.class_indices.keys()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, GaussianNoise, Input, MultiHeadAttention, Reshape
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

def create_mobilenet_model(input_shape):

    inputs = Input(shape=input_shape)
  
    base_model = MobileNet(weights='imagenet', input_tensor=inputs, include_top=False)
    
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output

    height, width, channels = 7, 7, 1024  
    x = Reshape((height * width, channels))(x)
   
    attention_output = MultiHeadAttention(num_heads=8, key_dim=channels)(x, x)

    attention_output = Reshape((height, width, channels))(attention_output)
    
    x = GaussianNoise(0.25)(attention_output)
    
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = GaussianNoise(0.25)(x)
    x = Dropout(0.25)(x)
    
    outputs = Dense(4, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)

    return model

input_shape = (224, 224, 3)

cnn_model = create_mobilenet_model(input_shape)

cnn_model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = cnn_model.fit(
    train_gen_new,
    validation_data=valid_gen_new,
    epochs=5,  
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/5
# I0000 00:00:1732456398.125702     391 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 1300 bytes spill stores, 1284 bytes spill loads
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8464 - loss: 0.4451
# I0000 00:00:1732456499.960409     442 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 1300 bytes spill stores, 1284 bytes spill loads
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 120s 77ms/step - accuracy: 0.8464 - loss: 0.4450 - val_accuracy: 0.9404 - val_loss: 0.1653
# Epoch 2/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 89s 69ms/step - accuracy: 0.9427 - loss: 0.1714 - val_accuracy: 0.9467 - val_loss: 0.1760
# Epoch 3/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 88s 68ms/step - accuracy: 0.9632 - loss: 0.1100 - val_accuracy: 0.9436 - val_loss: 0.1835
# Epoch 4/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 88s 69ms/step - accuracy: 0.9741 - loss: 0.0745 - val_accuracy: 0.9498 - val_loss: 0.1663
# Epoch 5/5
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 88s 68ms/step - accuracy: 0.9775 - loss: 0.0635 - val_accuracy: 0.9639 - val_loss: 0.1116

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
test_labels = test_gen_new.classes  
predictions = cnn_model.predict(test_gen_new)  
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step

# %%
report = classification_report(test_labels, predicted_classes, target_names=list(test_gen_new.class_indices.keys()))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       638
#            1       0.97      0.90      0.93       638
#            2       0.99      0.99      0.99       638
#            3       0.92      0.99      0.95       638
#
#     accuracy                           0.96      2552
#    macro avg       0.96      0.96      0.96      2552
# weighted avg       0.96      0.96      0.96      2552

# %%
conf_matrix = confusion_matrix(test_labels, predicted_classes)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=list(test_gen_new.class_indices.keys()), yticklabels=list(test_gen_new.class_indices.keys()))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
